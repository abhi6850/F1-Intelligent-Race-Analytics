# %%
import pandas as pd

df_clean = pd.read_csv("../data/processed/2023_season_laps_clean_stage1.csv")

df_clean.shape
# Out:
# (21695, 33)

# %%
df_clean["RaceName"].nunique()
df_clean["Driver"].nunique()
# Out:
# 22

# %%
df_clean.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# DeletedReason         21695
# PitOutTime            21695
# PitInTime             21695
# SpeedI1                3685
# SpeedST                1760
# Sector1SessionTime       48
# TyreLife                 35
# Compound                 35
# SpeedFL                   3
# Deleted                   0
# dtype: int64
