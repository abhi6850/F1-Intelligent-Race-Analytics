# %%
import pandas as pd
df = pd.read_csv("../data/processed/2023_pace_laps_features.csv")
df.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'Year', 'RaceName', 'LapTime_seconds',
#        'Sector1Time_seconds', 'Sector2Time_seconds', 'Sector3Time_seconds',
#        'TyreLifeSquared', 'LapInStint', 'Compound_encoded', 'Driver_encoded',
#        'Team_encoded'],
#       dtype='str')

# %%
import pandas as pd

df = pd.read_csv("../data/processed/2023_pace_laps_with_delta.csv")

df[[
    "RaceName",
    "LapTime_seconds",
    "TrackBaselineLapTime",
    "LapDelta_seconds"
]].head()
# Out:
#                RaceName  LapTime_seconds  TrackBaselineLapTime  \
# 0  Abu Dhabi Grand Prix           91.768             90.130325
# 1  Abu Dhabi Grand Prix           91.591             90.130325
# 2  Abu Dhabi Grand Prix           91.422             90.130325
# 3  Abu Dhabi Grand Prix           91.491             90.130325
# 4  Abu Dhabi Grand Prix           91.438             90.130325
#
#    LapDelta_seconds
# 0          1.637675
# 1          1.460675
# 2          1.291675
# 3          1.360675
# 4          1.307675

# %%
df["LapDelta_seconds"].describe()
# Out:
# count    2.166000e+04
# mean     2.663059e-15
# std      3.267410e+00
# min     -8.182535e+00
# 25%     -1.110494e+00
# 50%     -1.850181e-01
# 75%      7.317173e-01
# max      6.396783e+01
# Name: LapDelta_seconds, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("../data/processed/2023_pace_laps_with_delta_phase.csv")

df[[
    "RaceName",
    "LapNumber",
    "MaxLapInRace",
    "FuelProxy",
    "RaceProgress"
]].head()
# Out:
#                RaceName  LapNumber  MaxLapInRace  FuelProxy  RaceProgress
# 0  Abu Dhabi Grand Prix        3.0          58.0   0.948276      0.051724
# 1  Abu Dhabi Grand Prix        4.0          58.0   0.931034      0.068966
# 2  Abu Dhabi Grand Prix        5.0          58.0   0.913793      0.086207
# 3  Abu Dhabi Grand Prix        6.0          58.0   0.896552      0.103448
# 4  Abu Dhabi Grand Prix        7.0          58.0   0.879310      0.120690

# %%
df[["FuelProxy", "RaceProgress"]].describe()
# Out:
#           FuelProxy  RaceProgress
# count  21660.000000  21660.000000
# mean       0.480269      0.519731
# std        0.283073      0.283073
# min        0.000000      0.025641
# 25%        0.228571      0.280000
# 50%        0.482759      0.517241
# 75%        0.720000      0.771429
# max        0.974359      1.000000

# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/2023_pace_laps_with_delta_phase_trackcluster.csv"
)

df[["RaceName", "TrackCluster"]].drop_duplicates().sort_values("TrackCluster")
# Out:
#                        RaceName  TrackCluster
# 1800        Austrian Grand Prix             0
# 18588        Spanish Grand Prix             0
# 6142        Canadian Grand Prix             0
# 8239       Hungarian Grand Prix             0
# 15252        Pre-Season Testing             1
# 1032      Australian Grand Prix             1
# 2905      Azerbaijan Grand Prix             1
# 17640      Singapore Grand Prix             1
# 5355         British Grand Prix             1
# 12784          Miami Grand Prix             1
# 11661    Mexico City Grand Prix             2
# 7226           Dutch Grand Prix             2
# 13855         Monaco Grand Prix             2
# 19786      São Paulo Grand Prix             2
# 16039          Qatar Grand Prix             3
# 16826  Saudi Arabian Grand Prix             3
# 0          Abu Dhabi Grand Prix             3
# 10245       Japanese Grand Prix             3
# 9381         Italian Grand Prix             3
# ...
